# %% [markdown]
# ### 作業1：
#
# 資料：Heart Disease UCI   https://archive.ics.uci.edu/ml/datasets/Heart+Disease
#
# 1-1. 你選的這組資料為何重要
#
# Answer: 這組資料蒐集了病人的各種特徵與屬性，以及是否確實有罹患心臟病；如果我們可以根據這組資料的特徵建構出病人是否罹患心臟病的模型，日後就可以根據受測者的各項特徵值，更自動化、更準確地判斷是否該受測者有罹患心臟病。
#
# 1-2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# Answer: 資料是從幾位心臟病醫生搜尋病患的各種特徵與屬於而來。
#
# 1-3. 蒐集而來的資料型態為何
#
# Answer: 資料型態有三類，分別是類別資料、整數數值資料與浮點數數值資料。
#
# 1-4. 這組資料想解決的問題如何評估
#
# Answer: 用廻歸分析的方法，用前面13個欄位屬性的資料，來預測第十四個欄位 Target 的資料。用實際的Target值與預測的Target值是否正確來判斷準確率，用準備率來評斷預測模型的好壞。
#
#
# ### 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 2-1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# Answer: 先拆解目標，例如：車隊營收 = 車隊數量 x 車隊平均每天載客數 x 平均每趟的載客里程 x 每公里的車資，拆解之後，看看最有問題，最可以馬上改善的是哪個部分；其他很難改善的部分，再進一步拆解，直到找到最關鍵的議題。
#
# 2-2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# Answer: 資料從日常營運蒐集而來，營運資料會紀錄車隊上的每台車，每天的行車路線與載客紀錄；另外也會進一步紀錄乘客的叫車紀錄。
#
# 2-3. 蒐集而來的資料型態為何
#
# Answer: 有些是地理資訊，例如上車點與下車點；有些是類別資料，例如乘客的性別；有些是數值資料，例如搭車的距離、費用等。
#
# 2-4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# Answer:
# (1) 先前懷疑之所以整個車隊業績不好，是因為車輛過少，導致乘客需要更久的叫車時間，讓很多乘客就此放棄。
# (2) 所以我們假設乘客的叫車時間與車隊當時在線上的車子數量有關，驗證兩者是否有高度相關性。
# (3) 然後進一步驗證是否乘客叫車時間較短，叫車成行率就較高。
# (4) 如果上述兩者都成立，那關鍵就是車隊的數量，所以應該先用補貼或其他方式，想辦法把車隊數量建立起來，其他就會開始進入正向循環。
#
# ### 作業3：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔)
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)
#
#
#
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    MSE = sum(pow((y-y_hat),2))/len(y)
    return MSE

def mean_absolute_error(y,y_hat):
    MAE = sum(abs((y-y_hat)))/len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 285.472
# The Mean absolute error is 13.937
